# %% [markdown]
# # Part 4

# %% [markdown]
# In this section, we extend the HMM to have second-order dependencies by modifying the Viterbi algorithm.
#
# The logic is as follows:
# Our Viterbi algorithm thus far uses a first-order assumption, only including the probability of the previous state in the calculation of the likelihood of the current state. We want to now include the *previous two states* in our calculation.
#
# The algorithm can still be designed via dynamic programming. However, runtime is further multiplied by (number of states) due to the additional layer of multiplication, for a total runtime of $O(T \times |S|^3)$.

# %%
import os
import numpy as np
import pandas as pd
from collections import defaultdict
import re
# from tqdm import tqdm, trange
from tqdm import tqdm_notebook as tqdm, tnrange as trange
from IPython.display import display

# %%
# nltk stopwords
stopwords = {'it', 'before', "you're", 'wouldn', "hasn't", 'again', 'just', "you'd", 'only', "wouldn't", "isn't", 'no', 'yourself', 'them', 'in', 's', "aren't", 'because', 'ourselves', 'more', "couldn't", "shan't", "shouldn't", 'shan', 't', 'needn', "hadn't", 'both', 'such', 'below', 'out', 'my', "haven't", 'there', 'off', 'few', 'against', 'each', 'can', 'yourselves', 'some', 'further', 'if', 'under', 'over', 'theirs', 'his', 'herself', 'been', 'her', 'than', "you've", 'into', 'have', 'aren', 'and', 'then', 'whom', 'having', 'the', 'by', 'itself', 'him', 'up', 'be', "wasn't", 'me', 'of', 'haven', 'they', "mightn't", 'our', 'are', 'how', "weren't", 'couldn', 'too', "should've", 'until', 'weren', "that'll", 'a', 'when', "doesn't", 'which', 'here', 'was', 'hers', 'ain', 'mightn', 'those', 'himself', 'or', 'while', 'i', 'yours', 'from', 'once', 'after', 'does', 'its', 'to', 'you', 'myself', 'don', 'shouldn', 'most', 'that', 'mustn', 'same', "it's", 'what', 'any', 'did', 'isn', 'she', 'these', 'with', 'during', "needn't", 'your', 'their', 'being', 'on', 'above', 've', 'won', 'down', "she's", 're', 'this', 'do', 'hasn', 'had', 'so', 'other', 'an', 'were', 'hadn', 'themselves', 'will', 'as', 'for', 'at', 'd', 'm', 'but', 'ma', 'didn', 'll', 'not', "won't", 'ours', 'who', 'through', 'all', 'now', 'o', 'nor', "mustn't", "you'll", 'where', 'doesn', 'y', 'doing', 'why', 'between', "didn't", 'he', 'we', 'wasn', 'has', 'very', "don't", 'own', 'about', 'is', 'should', 'am'}
len(stopwords)
stopwords = {}
re_punc = r'^[^a-zA-Z0-9]+$'
re_hash = r'^#'
re_at = r'^@'
re_num = r'\d'  # just remove all words with numbers
re_url = r'(^http:|\.com$)'

# %%
def clean_word(w):
    w = w.strip()
    if w in stopwords:
        return '#STOP#'
    if re.match(re_punc, w):
        return '#PUNC#'
    if re.match(re_hash, w):
        return '#HASH#'
    if re.match(re_at, w):
        return '#AT#'
    if re.match(re_num, w):
        return '#NUM#'
    if re.match(re_url, w):
        return '#URL#'
    return w.lower()

# %%
dictionary = set()

# %% [markdown]
# ## Emissions
# We train the emissions matrix by using maximum likelihood estimation:
#
# $$ e(x|y) = \frac{Count(x->y)}{Count(y)} $$

# %%
# The behavior of the emissions matrix is the same - we use the same function as used in Part 3
def learn_emissions(train_filename):
    ''' Learns emissions parameters from data and returns them as a nested dictionary '''
    with open(train_filename, "r") as f:
        lines = f.readlines()

    observations = set()
    # Track emission counts
    emissions = {} # Where key is y, and value is a dictionary of emissions x from y with their frequency

    # Learn from data
    for line in tqdm(lines, desc='Emissions'):
        data_split = line.strip().rsplit(' ', 1)

        # Only process valid lines
        if len(data_split) == 2:
            obs, state = data_split
            obs = clean_word(obs)
            observations.add(obs)

            # Track this emission
            if state in emissions:
                current_emissions = emissions[state]
            else:
                current_emissions = defaultdict(int)
                
            if obs not in dictionary:
                dictionary.add(obs)
                current_emissions["#UNK#"] += 1
                
            current_emissions[obs] += 1
            emissions[state] = current_emissions # Update
    
    emission_counts = {k: sum(emissions[k].values()) for k in emissions}
    return emissions, emission_counts, observations


def get_emission_parameters(emissions, emission_counts, observations, x, y, k=1):
    ''' Returns the MLE of the emission parameters based on the emissions dictionary '''
    if y not in emissions:  # edge case: no records of emission from this state
        return 0
    state_data = emissions[y]
    count_y = emission_counts[y] #sum(state_data.values()) # Denominator
    
    if x not in observations:  # edge case: no records of emission of this word
        count_y_x = k
    else:
        count_y_x = state_data[x]
    
    e = count_y_x / (count_y + k)
    return e

# %% [markdown]
# ## Transitions

# %%
def learn_transitions(train_filename):
    """
    Returns a dictionary containing (key, value) where
        key: (t, u, v)
        value: Count(t, u, v)
    """
    with open(train_filename, 'r') as f:
        lines = f.readlines()
        
    transitions = defaultdict(int)
    prev_prev_state = 'PRESTART'
    prev_state = 'START'
    # avoid excessive indentations
    for line in tqdm(lines, desc='Transitions'):
        data_split = line.strip().rsplit(' ', 1)
        
        # line breaks -> new sequence
        if len(data_split) < 2:
            transitions[(prev_prev_state, prev_state, 'STOP')] += 1
            prev_prev_state = 'PRESTART'
            prev_state = 'START'
            continue

        obs, curr_state = data_split
        transitions[(prev_prev_state, prev_state, curr_state)] += 1
        prev_prev_state = prev_state
        prev_state = curr_state
        
    # count number of 'from' states
    transition_counts = defaultdict(int)
    for (t, u, v), counts in transitions.items():
        transition_counts[(t, u)] += counts

    # get all unique states
    t, u, v = zip(*transitions)
    states = set(t) | set(u) | set(v)
    return transitions, transition_counts, states

def get_transition_parameters(transitions, transition_counts, t, u, v):
    if transition_counts[(t, u)] == 0:  # edge case: no records of transitions starting from (t, u)
        return 0
    return transitions[(t, u, v)] / transition_counts[(t, u)]

# %% [markdown]
# We modify the Viterbi algorithm for Part 4, to include second-order dependencies.

# %% [markdown]
# ### Viterbi

# %%
# t, e = train('EN')
# transitions, transition_counts, states = t
# emissions, emission_counts, observations = e
# obs_seq = ['going', 'to', 'the', 'city']

def viterbi(transitions, transition_counts, states, emissions, emission_counts, observations, obs_seq):
    a = lambda prev2, prev, curr: get_transition_parameters(transitions, transition_counts, prev2, prev, curr)
    b = lambda state, out: get_emission_parameters(emissions, emission_counts, observations, y=state, x=out)

    # create empty tables
    n = len(obs_seq) + 2  # (PRESTART + START), (START, obs_seq[0]) + ... + (obs_seq[n], STOP) 

    state_combis = set()
    for u in states:
        for v in states:
            state_combis.add((u,v))
    P = pd.DataFrame(index=state_combis, columns=range(n)).fillna(0)  # probability table
    B = pd.DataFrame(index=state_combis, columns=range(n))  # backpointer table

    # initialization
    P.loc[('PRESTART', 'START'), 0] = 1

    # forward recursion
    sentence = []
    for j in range(1, n-1):
        x = clean_word(obs_seq[j-1])
        sentence.append(x)
        if x not in dictionary:
            x = "#UNK#"
        for v in states:  # curr state
            for u in states:  # prev state
                for t in states: # prev_2 state
                    p = P.loc[(t, u), j-1] * a(t, u, v) * b(v, x)
                    if p > P.loc[(u, v), j]:
                        P.loc[(u, v), j] = p  # update probability
                        B.loc[(u, v), j] = t  # update backpointer - t is the grandfather
    print(' '.join(sentence))

    # termination
    j = n - 1
    v = 'STOP'
    for u in states: # prev state
        for t in states: # prev_2 state
            p = P.loc[(t, u), j-1] * a(t, u, v)
            if p > P.loc[(u, v), j]:
                P.loc[(u, v), j] = p  # probability
                B.loc[(u, v), j] = t  # backpointer

    # backtracing
    # second order viterbi requires backpropagation keep track of the second order item, 
    # as the limited horizon assumption is now limited to *two* entries instead.
    state_pair = P[n-1].idxmax()
    state_seq = []
    for i in range(n-1, 0, -1):
        next_state = B.loc[state_pair, i]
        if isinstance(next_state, str):
            state_seq.append(state_pair[1])
            state_pair = (next_state, state_pair[0])
        else: # edge case: no possible transition to START
            for j in range(int(i)):
                state_seq.append(('O'))
            break
    state_seq = state_seq[::-1][:-1]  # reverse and drop STOP
    print(state_seq)
    return P, B, state_seq

# %%
# To get P rows with any not zeros:
# (P.loc[~(P==0).all(axis=1)])
# To get B rows with any not NAs:
# B.dropna(how='all')

# %%
def train(dataset):
    """
    Takes in dataset name, obtains transition and emission parameters.
    """
    train_filename = f'../data/{dataset}/train'
    # train
    t = learn_transitions(train_filename)
    e = learn_emissions(train_filename)
    return t, e


def validate(dataset, t, e):
    """
    Takes in dataset name, and HMM parameters.
    Use HMM parameters to estimate state sequence.
    Write state sequence to file alongside input observation sequence.
    """
    val_filename = f'../data/{dataset}/dev.in'
    out_filename = f'../data/{dataset}/dev.p4.out'

    # validate with train parameters
    label_sequence = lambda sentence: viterbi(*t, *e, sentence)
    
    # read validation file for sequence
    with open(val_filename, 'r') as f:
        lines = f.readlines()

    sentence = []
    result = []
    for word in tqdm(lines, desc=dataset):
        if word == '\n':
            print(sentence)
            _, _, s = label_sequence(sentence)  # ignore tables
            result.extend(s)
            result.append('\n')
            sentence = []
        else:
            sentence.append(word.strip())
            
    # write sequence to out file
    with open(out_filename, 'w') as f:
        for i in range(len(lines)):
            word = lines[i].strip()
            if word:
                pred = result[i]
                f.write(word + ' ' + pred)
            f.write('\n')

# %%
datasets = ['EN', 'FR']
for dataset in datasets:
    t, e = train(dataset)
    validate(dataset, t, e)
# Out:
# HBox(children=(IntProgress(value=0, description='Transitions', max=11236, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='Emissions', max=11236, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='EN', max=1520, style=ProgressStyle(description_width='initial…
# ['NO', 'Saints', 'R', '.', 'Buch', 'might', 'come', 'back', 'n', 'play', 'vs', 'Seahawks', 'on', 'Sunday', '??']
# no saints r #PUNC# buch might come back n play vs seahawks on sunday #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Polling', 'ends', 'in', 'Bihar', 'today', ',', 'counting', 'on', 'November', '24', 'http://toi.in/ujtwya']
# polling ends in bihar today #PUNC# counting on november #NUM# #URL#
# ['B-NP', 'B-VP', 'B-PP', 'B-NP', 'B-NP', 'O', 'B-NP', 'B-PP', 'B-NP', 'I-NP', 'O']
# ['Today', 'has', 'been', 'a', 'GREAT', 'day', '__AND__', 'it', 'just', 'keeps', 'getting', 'better', '!!!', 'Thank', 'You', 'Lord', '!']
# today has been a great day __and__ it just keeps getting better #PUNC# thank you lord #PUNC#
# ['B-NP', 'B-VP', 'I-VP', 'B-NP', 'I-NP', 'I-NP', 'O', 'B-NP', 'B-ADVP', 'I-ADVP', 'B-VP', 'B-ADJP', 'O', 'B-VP', 'B-NP', 'B-NP', 'O']
# ['man', 'my', 'twin', 'wanna', 'act', 'fake', 'today', 'but', 'its', 'okay', 'bcuz', 'i', 'still', 'love', 'you']
# man my twin wanna act fake today but its okay bcuz i still love you
# ['B-INTJ', 'B-NP', 'I-NP', 'B-VP', 'B-PP', 'I-PP', 'B-NP', 'O', 'B-NP', 'I-NP', 'B-PP', 'B-NP', 'B-ADVP', 'B-VP', 'B-NP']
# ['@iians', 'Id', 'love', 'to', 'see', 'IDWT', 'live', 'from', 'CES', '.', 'And', 'one', 'day', 'I', 'hope', 'to', 'go', 'to', 'ces', 'myself', '.']
# #AT# id love to see idwt live from ces #PUNC# and one day i hope to go to ces myself #PUNC#
# ['O', 'B-NP', 'B-VP', 'I-VP', 'I-VP', 'I-VP', 'I-VP', 'B-PP', 'B-NP', 'O', 'O', 'B-NP', 'I-NP', 'B-NP', 'B-VP', 'I-VP', 'I-VP', 'I-VP', 'B-PRT', 'B-NP', 'O']
# ['@Team_Panic', 'omg', ',', 'i', 'wish', 'i', 'got', 'paid', 'to', 'freak', 'people', 'out', '.', 'it', "'s", 'so', 'funny', 'when', 'they', 'think', "you'r", 'serious', '.', 'noobs', '.']
# #AT# omg #PUNC# i wish i got paid to freak people out #PUNC# it 's so funny when they think you'r serious #PUNC# noobs #PUNC#
# ['O', 'B-INTJ', 'O', 'B-NP', 'B-VP', 'B-NP', 'B-VP', 'I-VP', 'I-VP', 'I-VP', 'B-NP', 'B-PRT', 'O', 'B-NP', 'B-VP', 'B-ADJP', 'I-ADJP', 'B-ADVP', 'B-NP', 'B-VP', 'B-NP', 'I-NP', 'O', 'O', 'O']
# ['fckn', 'emily', 'rodriguez', 'did', "n't", 'bring', 'my', 'cookies', 'today', '!!', 'lil', 'brat', '.']
# fckn emily rodriguez did n't bring my cookies today #PUNC# lil brat #PUNC#
# ['B-INTJ', 'I-INTJ', 'I-INTJ', 'B-VP', 'I-VP', 'I-VP', 'B-NP', 'B-PP', 'B-NP', 'I-NP', 'I-NP', 'I-NP', 'O']
# ['Amazon', 'U.K.', 'Offering', 'HTC', 'Desire', 'Z', 'Unlocked', 'October', '11', ':', 'We', 'just', 'got', 'official', 'word', 'of', 'the', 'HTC', 'Desire', 'Z', 'earlier', 'in', 'Lo', '...', 'http://bit.ly/bsyz9H']
# amazon u.k. offering htc desire z unlocked october #NUM# #PUNC# we just got official word of the htc desire z earlier in lo #PUNC# #URL#
# ['B-NP', 'B-VP', 'I-VP', 'B-ADJP', 'I-ADJP', 'B-PP', 'I-PP', 'B-NP', 'I-NP', 'O', 'B-NP', 'B-ADVP', 'B-VP', 'B-NP', 'B-NP', 'B-PP', 'B-NP', 'I-NP', 'B-ADVP', 'I-ADVP', 'I-ADVP', 'B-PP', 'B-ADVP', 'O', 'O']
# ['Lmao', '..', 'They', '#Hurrt', '!', 'RT', '@_sofucKENNrude', 'y', 'every', 'nigga', 'tryna', 'grow', 'they', 'hair', 'out', '.', 'should', 'of', 'did', 'that', 'a', 'long', 'time', 'ago', '.', '-_-', 'skimp', 'ass', 'braids', '.']
# lmao #PUNC# they #HASH# #PUNC# rt #AT# y every nigga tryna grow they hair out #PUNC# should of did that a long time ago #PUNC# #PUNC# skimp ass braids #PUNC#
# ['B-INTJ', 'O', 'B-NP', 'O', 'O', 'O', 'O', 'B-ADVP', 'B-NP', 'B-VP', 'I-VP', 'B-PRT', 'B-NP', 'I-NP', 'B-PRT', 'O', 'B-VP', 'B-PP', 'B-VP', 'B-NP', 'B-NP', 'I-NP', 'I-NP', 'B-ADVP', 'O', 'O', 'B-NP', 'I-NP', 'I-NP', 'O']
# ['@', 'home', 'chilling', 'guess', 'I', "'m", 'staying', 'in', '2day', '2', 'rest', 'this', 'week', 'was', 'crazy', 'but', 'I', "'m", 'ready', 'for', 'dis', 'weekend']
# #PUNC# home chilling guess i 'm staying in #NUM# #NUM# rest this week was crazy but i 'm ready for dis weekend
# ['O', 'B-NP', 'B-VP', 'B-VP', 'B-NP', 'B-VP', 'I-VP', 'B-PP', 'B-NP', 'I-NP', 'I-NP', 'B-NP', 'I-NP', 'B-VP', 'B-ADJP', 'O', 'B-NP', 'B-VP', 'B-ADJP', 'B-PP', 'B-NP', 'I-NP']
# ['On', 'Thanksgiving', 'after', 'you', 'done', 'eating', 'its', '#TimeToGetOut', 'unless', 'you', 'wanna', 'help', 'with', 'the', 'dishes']
# on thanksgiving after you done eating its #HASH# unless you wanna help with the dishes
# ['B-ADJP', 'I-ADJP', 'B-SBAR', 'B-NP', 'B-VP', 'B-VP', 'B-NP', 'O', 'B-SBAR', 'B-NP', 'B-VP', 'I-VP', 'B-PP', 'B-NP', 'O']
# ['Got', 'another', 'two', 'box', 'of', 'chocolate', 'from', 'sister', '.', '.', 'Rewind', 'the', '1st', 'time', 'I', 'gave', 'you', 'a', 'bar', 'of', 'chocolate', '.', '.', 'Everything', 'pratically', 'remind', 'me', 'of', 'you', '?']
# got another two box of chocolate from sister #PUNC# #PUNC# rewind the #NUM# time i gave you a bar of chocolate #PUNC# #PUNC# everything pratically remind me of you #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['tomorrow', 'no', 'school', 'for', 'me', 'but', 'I', "'m", 'so', 'anxious', 'beacuse', 'of', 'tomorrow', 'omg', ':/']
# tomorrow no school for me but i 'm so anxious beacuse of tomorrow omg #PUNC#
# ['B-NP', 'B-NP', 'I-NP', 'B-PP', 'B-NP', 'O', 'B-NP', 'B-VP', 'B-ADJP', 'I-ADJP', 'I-ADJP', 'B-PP', 'B-NP', 'B-INTJ', 'O']
# ['PREACH', '!!', 'RT', '@DJRyan1der', ':', 'These', 'ppl', 'do', "n't", 'understand', 'its', 'Monday', 'and', 'I', "'m", 'not', 'in', 'da', 'mood', 'to', 'deal', 'wit', 'their', 'bullshit', '!!', 'Fukk', 'outta', 'here', '!!!']
# preach #PUNC# rt #AT# #PUNC# these ppl do n't understand its monday and i 'm not in da mood to deal wit their bullshit #PUNC# fukk outta here #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'B-NP', 'I-NP', 'B-VP', 'I-VP', 'B-PRT', 'B-NP', 'I-NP', 'O', 'B-NP', 'B-VP', 'I-VP', 'B-PP', 'B-NP', 'I-NP', 'B-VP', 'I-VP', 'B-PP', 'B-NP', 'I-NP', 'O', 'B-ADJP', 'B-PP', 'B-ADVP', 'O']
# ['The', 'guys', 'are', 'cooking', 'about', 'a', 'dozen', 'pizzas', 'at', 'our', 'house', 'for', 'the', 'tailgate', 'tonight', '.', 'Nonetheless', 'it', 'smells', 'fresh', 'in', 'this', 'place', '.']
# the guys are cooking about a dozen pizzas at our house for the tailgate tonight #PUNC# nonetheless it smells fresh in this place #PUNC#
# ['B-NP', 'B-NP', 'B-VP', 'I-NP', 'B-PP', 'B-NP', 'B-SBAR', 'I-SBAR', 'B-NP', 'B-NP', 'I-NP', 'B-PP', 'B-NP', 'I-NP', 'B-NP', 'O', 'B-ADVP', 'B-NP', 'B-ADVP', 'B-VP', 'B-PP', 'B-NP', 'I-NP', 'O']
# ['Think', "I'ma", 'make', '@GrownWomanStuff', 'have', 'a', 'shoegasm', 'today', 'hahahaha']
# think i'ma make #AT# have a shoegasm today hahahaha
# ['B-VP', 'I-VP', 'I-VP', 'O', 'B-VP', 'B-NP', 'B-PP', 'B-NP', 'O']
# ['even', 'better', 'than', 'cocktail', 'friday', '!', 'http://is.gd/ffDb9']
# even better than cocktail friday #PUNC# #URL#
# ['B-ADJP', 'I-ADJP', 'B-PP', 'I-PP', 'B-NP', 'O', 'O']
# ['I', 'kept', 'telling', 'niggers', "it'd", 'happen', '.', 'Come', 'Thursday', 'im', 'inna', 'boardroom', 'full', 'of', 'niggers', '3times', 'my', 'age', '.', '.', '.', 'at', 'the', 'tender', 'age', 'of', '17', '!!', 'Im', 'pleased', '.']
# i kept telling niggers it'd happen #PUNC# come thursday im inna boardroom full of niggers #NUM# my age #PUNC# #PUNC# #PUNC# at the tender age of #NUM# #PUNC# im pleased #PUNC#
# ['B-NP', 'I-NP', 'B-CONJP', 'I-CONJP', 'B-VP', 'I-VP', 'O', 'B-VP', 'B-NP', 'B-NP', 'B-VP', 'I-VP', 'B-ADJP', 'B-PP', 'B-NP', 'I-NP', 'B-NP', 'B-NP', 'O', 'O', 'O', 'B-PP', 'B-NP', 'B-PP', 'B-NP', 'B-PP', 'B-NP', 'O', 'B-NP', 'I-NP', 'O']
# ['Shower', 'time', 'the', 'flyin', 'pilot', 'I', 'was', 'at', 'last', 'night', 'did', "n't", 'have', 'no', 'hot', 'water', 'uggghh']
# shower time the flyin pilot i was at last night did n't have no hot water uggghh
# ['B-NP', 'I-NP', 'B-NP', 'B-SBAR', 'I-SBAR', 'B-NP', 'B-VP', 'B-PP', 'B-NP', 'I-NP', 'B-VP', 'I-VP', 'I-VP', 'B-NP', 'B-ADJP', 'B-NP', 'O']
# ['@hime8644', 'LOL', 'theres', 'always', 'some', 'good', 'vids', 'I', 'didnt', 'see', 'before', 'like', 'this', 'one', 'XD', '---', '&gt;', 'http://www.youtube.com/watch?v=8zJKZJ7TGlU', 'OMG', '*DROOLS*']
# #AT# lol theres always some good vids i didnt see before like this one xd #PUNC# &gt; #URL# omg *drools*
# ['O', 'B-INTJ', 'I-INTJ', 'B-ADVP', 'B-NP', 'I-NP', 'B-SBAR', 'B-NP', 'B-VP', 'I-VP', 'B-PP', 'B-PP', 'B-NP', 'I-NP', 'B-INTJ', 'O', 'B-INTJ', 'O', 'B-INTJ', 'I-INTJ']
# ['It', 'is', 'Friday', 'afternoon', 'adn', 'I', 'could', "n't", 'be', 'happier', '.', 'Ending', 'a', 'crappy', 'week', 'on', 'a', 'good', 'note', 'is', 'always', 'nice', '.']
# it is friday afternoon adn i could n't be happier #PUNC# ending a crappy week on a good note is always nice #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['LADY', 'GAGA', 'IS', 'BETTER', 'THE', '5th', 'TIME', 'OH', 'BABY(', ':']
# lady gaga is better the #NUM# time oh baby( #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Pope', 'says', 'religion', "'", "marginalized':", 'That', "'s", 'why', 'he', 'ca', "n't", 'get', 'a', 'headline', 'printed', 'anywhere', ',', 'because', 'religion', 'is', 'so', 'mar', '...', 'http://bit.ly/cBvt1u']
# pope says religion #PUNC# marginalized': that 's why he ca n't get a headline printed anywhere #PUNC# because religion is so mar #PUNC# #URL#
# ['B-NP', 'B-ADJP', 'I-ADJP', 'O', 'B-SBAR', 'B-NP', 'B-VP', 'B-ADVP', 'B-NP', 'B-VP', 'I-VP', 'I-VP', 'B-NP', 'B-ADJP', 'I-ADJP', 'I-ADJP', 'O', 'B-SBAR', 'B-NP', 'B-VP', 'B-ADJP', 'I-ADJP', 'O', 'O']
# ['@ashhleybrookee', 'it', 'may', 'be', 'nasty', 'but', '...', 'it', 'works', '.']
# #AT# it may be nasty but #PUNC# it works #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['So', 'this', 'will', 'be', 'more', 'lhs', 'games', 'then', 'i', 'went', 'to', 'then', 'when', 'i', 'went', 'to', 'lhs']
# so this will be more lhs games then i went to then when i went to lhs
# ['O', 'B-NP', 'B-VP', 'I-VP', 'B-ADJP', 'I-ADJP', 'I-ADJP', 'O', 'B-NP', 'B-VP', 'I-VP', 'O', 'B-ADVP', 'B-NP', 'B-VP', 'I-VP', 'B-PRT']
# ['RT', '@DamnTeenQuotes', ':', 'I', 'remember', 'when', 'i', 'was', 'your', 'age', ',', 'spencer', 'from', 'iCarly', 'was', 'Crazy', 'Steve', ',', 'Carly', 'was', 'Megan', 'and', 'Josh', 'was', 'fat', '.', '#damnteenquotes']
# rt #AT# #PUNC# i remember when i was your age #PUNC# spencer from icarly was crazy steve #PUNC# carly was megan and josh was fat #PUNC# #HASH#
# ['O', 'O', 'O', 'B-NP', 'B-VP', 'B-ADVP', 'B-NP', 'B-VP', 'B-NP', 'B-NP', 'O', 'B-VP', 'B-PP', 'B-NP', 'B-VP', 'B-ADJP', 'B-NP', 'O', 'B-NP', 'B-VP', 'B-ADJP', 'O', 'B-NP', 'B-VP', 'I-NP', 'I-NP', 'O']
# ['[', 'GigaOM', ']', 'DRM', 'FAIL', ':', 'Five', 'Broken', 'Copy', 'Protection', 'Schemes', ':', 'This', 'week', ',', 'we', 'learned', 'that', 'the', 'HDCP', 'copy', 'protection', 'scheme', '...', 'http://bit.ly/blWf0e']
# #PUNC# gigaom #PUNC# drm fail #PUNC# five broken copy protection schemes #PUNC# this week #PUNC# we learned that the hdcp copy protection scheme #PUNC# #URL#
# ['O', 'B-INTJ', 'O', 'B-INTJ', 'I-INTJ', 'O', 'B-NP', 'I-NP', 'I-NP', 'B-ADVP', 'I-ADVP', 'O', 'B-NP', 'I-NP', 'O', 'B-NP', 'B-VP', 'B-SBAR', 'B-NP', 'I-NP', 'I-NP', 'B-ADVP', 'I-ADVP', 'O', 'O']
# ['Friday', 'Night', 'Eats', 'http://twitpic.com/2pdvtr']
# friday night eats #URL#
# ['B-NP', 'I-NP', 'I-NP', 'O']
# ['I', 'remember', 'when', 'you', 'all', 'were', 'thiiis', 'big', ',', 'you', 'know', '?']
# i remember when you all were thiiis big #PUNC# you know #PUNC#
# ['B-NP', 'B-VP', 'B-ADVP', 'B-NP', 'B-NP', 'B-VP', 'B-PRT', 'B-NP', 'O', 'B-NP', 'B-VP', 'O']
# ['RT', '@PeepsMagoo', ':', 'Please', 'help', 'me', 'save', 'Sunshine', '.', 'She', 'is', 'scheduled', 'to', 'be', 'put', 'down', 'at', 'a', 'Camarillo', 'shelter', 'on', 'Jan', '6', 'http://fragurl.com/5P']
# rt #AT# #PUNC# please help me save sunshine #PUNC# she is scheduled to be put down at a camarillo shelter on jan #NUM# #URL#
# ['O', 'O', 'O', 'B-VP', 'I-VP', 'B-NP', 'I-NP', 'I-NP', 'O', 'B-NP', 'B-VP', 'I-VP', 'I-VP', 'I-VP', 'B-VP', 'B-ADVP', 'B-PP', 'B-NP', 'I-NP', 'I-NP', 'B-PP', 'B-NP', 'I-NP', 'O']
# ['I', 'have', 'a', 'strong', 'hunch', 'Adam', 'will', 'be', 'a', 'story', 'on', 'TMZ', 'tonight', '.', 'Gulp', '.']
# i have a strong hunch adam will be a story on tmz tonight #PUNC# gulp #PUNC#
# ['B-NP', 'B-VP', 'B-ADJP', 'I-ADJP', 'I-ADJP', 'I-ADJP', 'B-VP', 'I-VP', 'B-NP', 'I-NP', 'B-PP', 'B-NP', 'B-NP', 'O', 'B-INTJ', 'O']
# ['WIN', 'FREE', 'PAMPERS', 'FOR', 'A', 'YEAR', '!!!', 'And', 'more', '...', 'http://nblo.gs/80qJu']
# win free pampers for a year #PUNC# and more #PUNC# #URL#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['holy', 'FUCK', 'THIS', 'IS', 'THE', 'MOST', 'BORING', 'DAY', 'EVER', '.']
# holy fuck this is the most boring day ever #PUNC#
# ['O', 'B-INTJ', 'B-NP', 'B-VP', 'B-NP', 'I-NP', 'I-NP', 'I-NP', 'B-ADVP', 'O']
# ['A', 'TRUE', 'friend', 'walks', 'in', 'when', 'everybody', 'else', 'walks', 'out', '!']
# a true friend walks in when everybody else walks out #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['#Astros', 'lineup', 'for', 'tonight', '.', 'Keppinger', 'sits', ',', 'Downs', 'plays', '2B', ',', 'CJ', 'bats', '5th', '.', '@alysonfooter', 'http://bit.ly/bHvgCS']
# #HASH# lineup for tonight #PUNC# keppinger sits #PUNC# downs plays #NUM# #PUNC# cj bats #NUM# #PUNC# #AT# #URL#
# ['O', 'B-INTJ', 'B-PP', 'B-NP', 'O', 'B-ADJP', 'I-ADJP', 'B-PP', 'I-PP', 'I-PP', 'B-NP', 'O', 'B-INTJ', 'I-INTJ', 'I-INTJ', 'O', 'O', 'O']
# ['RT', '@rockerfuckerak', ':', 'What', "'s", 'done', 'is', 'done', ',', 'Just', 'leave', 'it', 'alone', ',', 'and', 'do', "n't", 'regret', '.', 'Sometimes', 'somethings', 'turn', 'in-to', 'dumb', 'things', '.', 'And', 'that', "'s", 'when', '...']
# rt #AT# #PUNC# what 's done is done #PUNC# just leave it alone #PUNC# and do n't regret #PUNC# sometimes somethings turn in-to dumb things #PUNC# and that 's when #PUNC#
# ['O', 'O', 'O', 'B-NP', 'B-VP', 'B-VP', 'O', 'B-VP', 'O', 'B-VP', 'I-VP', 'B-NP', 'B-PRT', 'O', 'O', 'B-VP', 'I-VP', 'B-NP', 'I-NP', 'B-CONJP', 'I-CONJP', 'B-VP', 'B-NP', 'B-ADJP', 'B-NP', 'O', 'O', 'B-NP', 'B-VP', 'B-ADVP', 'O']
# ['Long', '18k', 'run', 'done', 'and', 'in', 'the', 'books', '!', 'Beauty', 'day', '.', 'Til', 'now', ',', 'at', 'dentist', ',', 'and', 'lady', 'next', 'to', 'me', 'spilling', 'over', 'to', 'my', 'chair', '..', 'Just', 'belched', '.', 'Loudly', '.', '+1']
# long #NUM# run done and in the books #PUNC# beauty day #PUNC# til now #PUNC# at dentist #PUNC# and lady next to me spilling over to my chair #PUNC# just belched #PUNC# loudly #PUNC# +1
# ['B-NP', 'B-VP', 'I-VP', 'B-VP', 'B-ADVP', 'B-PP', 'B-NP', 'I-NP', 'O', 'B-NP', 'I-NP', 'O', 'B-PP', 'B-NP', 'O', 'B-PP', 'B-NP', 'I-NP', 'I-NP', 'I-NP', 'I-NP', 'B-PP', 'B-NP', 'I-NP', 'B-PP', 'B-VP', 'B-NP', 'B-PRT', 'O', 'B-ADVP', 'I-ADVP', 'O', 'B-INTJ', 'I-INTJ', 'I-INTJ']
# ['RT', '@JupiterStorm', ':', '1', '.', '6', '.', '2011', '.', 'The', 'day', '@owlcity', 'went', 'on', 'an', 'Emporer', "'s", 'New', 'Groove', 'rampage', 'through', 'twitter', '.', 'xD']
# rt #AT# #PUNC# #NUM# #PUNC# #NUM# #PUNC# #NUM# #PUNC# the day #AT# went on an emporer 's new groove rampage through twitter #PUNC# xd
# ['O', 'O', 'O', 'B-NP', 'O', 'B-NP', 'O', 'B-NP', 'O', 'B-NP', 'I-NP', 'O', 'B-VP', 'B-PP', 'B-NP', 'I-NP', 'B-VP', 'B-ADJP', 'I-ADJP', 'I-ADJP', 'B-PP', 'B-NP', 'O', 'B-INTJ']
# ['hows', 'everyones', 'day', 'goin', '?']
# hows everyones day goin #PUNC#
# ['B-INTJ', 'I-INTJ', 'B-NP', 'B-VP', 'O']
# ['@PERSONGUY6661', 'I', 'have', "n't", 'unfortunately', ':(', 'I', 'missed', 'the', 'chance', 'when', 'theycame', 'to', 'the', 'uk', 'this', 'year', ',', 'you', 'seen', 'them', '?']
# #AT# i have n't unfortunately #PUNC# i missed the chance when theycame to the uk this year #PUNC# you seen them #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['@Yeweezii', 'Jst', 'lock', 'her', 'outside', '4', 'd', 'nite', '.', 'It', 'workz', 'al', 'd', 'time', ':-D']
# #AT# jst lock her outside #NUM# d nite #PUNC# it workz al d time :-d
# ['O', 'B-ADVP', 'I-ADVP', 'B-NP', 'B-PP', 'B-NP', 'B-NP', 'B-INTJ', 'O', 'B-NP', 'I-NP', 'I-NP', 'B-NP', 'I-NP', 'O']
# ['@keancipriano', 'hey', ':)', 'where', 'exactly', 'is', 'your', 'gig', 'tonight', '?', ':)']
# #AT# hey #PUNC# where exactly is your gig tonight #PUNC# #PUNC#
# ['O', 'B-INTJ', 'B-NP', 'B-ADVP', 'B-INTJ', 'O', 'B-NP', 'B-VP', 'B-NP', 'O', 'O']
# ['@YoDayDay', 'Nope', '!', '*lil', 'kid', 'voice*', 'im', 'being', 'stingy', 'tonight', '!!', '*hmph*']
# #AT# nope #PUNC# *lil kid voice* im being stingy tonight #PUNC# *hmph*
# ['O', 'B-INTJ', 'O', 'B-ADVP', 'B-NP', 'B-ADVP', 'B-NP', 'B-VP', 'B-PRT', 'B-NP', 'O', 'B-INTJ']
# ['@Phoebe1_', 'and', 'i', 'also', 'loved', 'the', 'last', 'years', 'eurovision', 'entry', '!!', 'hoppaa', '!', 'they', 'were', 'cool', 'too', '!!']
# #AT# and i also loved the last years eurovision entry #PUNC# hoppaa #PUNC# they were cool too #PUNC#
# ['O', 'O', 'B-NP', 'B-ADVP', 'B-VP', 'B-NP', 'I-NP', 'I-NP', 'B-ADVP', 'I-ADVP', 'O', 'B-INTJ', 'O', 'B-NP', 'B-VP', 'B-ADJP', 'B-NP', 'O']
# ['"', '@DJDROC', ':', '#beforeserato', 'djs', 'actually', 'used', 'headphones', 'believe', 'it', 'or', 'not', '"', '---', 'except', 'majestic', 'and', 'me', 'when', 'we', 'were', 'drunk', '...', 'haha']
# #PUNC# #AT# #PUNC# #HASH# djs actually used headphones believe it or not #PUNC# #PUNC# except majestic and me when we were drunk #PUNC# haha
# ['O', 'O', 'O', 'O', 'O', 'B-ADVP', 'B-VP', 'I-VP', 'I-VP', 'B-NP', 'I-NP', 'O', 'O', 'O', 'B-ADVP', 'I-ADVP', 'I-ADVP', 'B-NP', 'B-ADVP', 'B-NP', 'B-VP', 'B-ADJP', 'O', 'B-INTJ']
# ['RT', '@robmoysey', 'Eyeopener', 'vs', '.', 'Ryerson', 'Quidditch', 'team', 'this', 'Sunday', 'at', '4', 'p.m.', 'Anyone', 'know', 'where', 'to', 'get', 'cheap', 'brooms', '?', '#Ryerson', '@RUQuidditch', '#Rams']
# rt #AT# eyeopener vs #PUNC# ryerson quidditch team this sunday at #NUM# p.m. anyone know where to get cheap brooms #PUNC# #HASH# #AT# #HASH#
# ['O', 'O', 'B-NP', 'I-NP', 'O', 'B-NP', 'I-NP', 'I-NP', 'O', 'B-NP', 'B-PP', 'B-NP', 'I-NP', 'B-NP', 'B-VP', 'B-ADVP', 'B-PP', 'B-VP', 'B-ADJP', 'I-ADJP', 'O', 'O', 'O', 'O']
# ['@yoopergirl89', 'Yeah', 'it', 'was', 'a', 'long', 'week', 'here', 'too', '.', 'Luckily', 'for', 'me', 'next', 'is', 'only', 'Monday', '__AND__', 'Tuesday', 'week', '.']
# #AT# yeah it was a long week here too #PUNC# luckily for me next is only monday __and__ tuesday week #PUNC#
# ['O', 'B-INTJ', 'B-NP', 'B-VP', 'B-NP', 'I-NP', 'I-NP', 'B-ADVP', 'B-ADVP', 'O', 'B-ADJP', 'B-PP', 'B-NP', 'I-NP', 'B-VP', 'B-NP', 'I-NP', 'O', 'B-NP', 'I-NP', 'O']
# ['Day', 'One', ':', 'Ten', 'things', 'you', 'want', 'to', 'say', 'to', 'ten', 'different', 'people', 'right', 'now', '-', '1', ')', 'Eduardo', 'Surita', ':', 'your', 'a', 'freaking', '...', 'http://tumblr.com/xmciuda0t']
# day one #PUNC# ten things you want to say to ten different people right now #PUNC# #NUM# #PUNC# eduardo surita #PUNC# your a freaking #PUNC# #URL#
# ['B-NP', 'I-NP', 'O', 'B-VP', 'B-NP', 'B-NP', 'B-VP', 'I-VP', 'I-VP', 'I-VP', 'B-PRT', 'B-NP', 'I-NP', 'B-ADVP', 'I-ADVP', 'O', 'B-NP', 'O', 'B-INTJ', 'I-INTJ', 'O', 'B-NP', 'B-ADJP', 'I-ADJP', 'O', 'O']
# ['Our', 'Favorite', 'YouTube', 'Videos', 'This', 'Week', ':', 'The', 'Drama', 'Edition', 'http://dlvr.it/5RfHy']
# our favorite youtube videos this week #PUNC# the drama edition #URL#
# ['B-NP', 'I-NP', 'B-NP', 'B-PP', 'B-NP', 'I-NP', 'O', 'B-NP', 'B-NP', 'I-NP', 'O']
# ['I', 'just', 'took', '"', 'After', 'getting', 'trampled', 'at', 'a', 'Justin', 'Bieber', 'concert', ',', 'yoiu', 'wake', 'up', 'and', '..."', 'and', 'got', ':', 'Part', '6', ':)', '!', 'Try', 'it', ':', 'http://tinyurl.com/233u5lu']
# i just took #PUNC# after getting trampled at a justin bieber concert #PUNC# yoiu wake up and #PUNC# and got #PUNC# part #NUM# #PUNC# #PUNC# try it #PUNC# #URL#
# ['B-NP', 'B-ADVP', 'B-VP', 'O', 'B-PP', 'B-VP', 'I-VP', 'B-PP', 'B-NP', 'I-NP', 'I-NP', 'I-NP', 'O', 'B-NP', 'B-VP', 'B-PRT', 'O', 'O', 'O', 'B-VP', 'O', 'B-NP', 'I-NP', 'O', 'O', 'B-VP', 'B-NP', 'O', 'O']
# ['My', 'first', 'assignment', 'was', 'a', 'medical', 'illustration', 'job', 'through', 'a', 'friend', '.', 'After', 'meeting', 'with', 'the', 'surgeon', ',', 'I', 'comple', '...']
# my first assignment was a medical illustration job through a friend #PUNC# after meeting with the surgeon #PUNC# i comple #PUNC#
# ['B-NP', 'I-NP', 'B-ADVP', 'B-VP', 'B-NP', 'B-PP', 'B-NP', 'I-NP', 'B-PP', 'B-NP', 'I-NP', 'O', 'B-PP', 'B-VP', 'B-PP', 'B-NP', 'I-NP', 'O', 'B-NP', 'I-NP', 'O']
# ['@Elinor_Althani', 'ahhhh', 'reading', ',', 'still', 'i', 'did', "n't", 'finish', 'my', 'book', '=(', 'i', 'have', 'to', 'do', 'it', 'before', 'Feb', 'ends', 'inshallah', ':)']
# #AT# ahhhh reading #PUNC# still i did n't finish my book #PUNC# i have to do it before feb ends inshallah #PUNC#
# ['O', 'B-ADVP', 'B-VP', 'O', 'B-ADVP', 'B-NP', 'B-VP', 'I-VP', 'B-PRT', 'B-NP', 'I-NP', 'O', 'B-NP', 'B-VP', 'I-VP', 'I-VP', 'B-NP', 'B-SBAR', 'B-NP', 'B-VP', 'B-ADJP', 'O']
# ['@justinbieber', 'I', 'have', 'this', 'on', 'my', 'computer', ',', 'it', 'gives', 'me', 'days', ',', 'hours', ',', 'mintues', '__AND__', 'seconds', 'till', 'Feb', '9th', '!', '#purpleglasses', 'http://twitpic.com/3nouem']
# #AT# i have this on my computer #PUNC# it gives me days #PUNC# hours #PUNC# mintues __and__ seconds till feb #NUM# #PUNC# #HASH# #URL#
# ['O', 'B-NP', 'B-VP', 'B-NP', 'B-PP', 'B-NP', 'I-NP', 'O', 'B-NP', 'B-VP', 'B-NP', 'I-NP', 'I-NP', 'I-NP', 'O', 'B-INTJ', 'O', 'B-INTJ', 'B-PP', 'B-NP', 'I-NP', 'O', 'O', 'O']
# ['i', 'see', 'some', 'ppl', 'celebrating', 'their', 'birthdays', 'like', '2-3', 'times', 'a', 'year', '...', 'WTF', '?!']
# i see some ppl celebrating their birthdays like #NUM# times a year #PUNC# wtf #PUNC#
# ['B-NP', 'B-VP', 'B-NP', 'I-NP', 'B-PP', 'B-NP', 'I-NP', 'B-PP', 'B-NP', 'I-NP', 'B-NP', 'I-NP', 'O', 'B-INTJ', 'O']
# ['Class', ',', 'intelligence', ',', 'honesty', ',', 'and', 'morals', 'are', 'non', 'existent', 'these', 'days', '.']
# class #PUNC# intelligence #PUNC# honesty #PUNC# and morals are non existent these days #PUNC#
# ['B-NP', 'O', 'B-INTJ', 'O', 'B-INTJ', 'I-INTJ', 'O', 'B-ADVP', 'B-VP', 'B-PP', 'I-PP', 'B-NP', 'I-NP', 'O']
# ['still', 'fly', 'from', 'yesterday', '....', 'same', 'clothes', 'from', 'yesterday', '...', 'lmao']
# still fly from yesterday #PUNC# same clothes from yesterday #PUNC# lmao
# ['B-ADVP', 'B-VP', 'B-PP', 'B-NP', 'O', 'B-NP', 'B-ADJP', 'B-PP', 'B-NP', 'O', 'B-INTJ']
# ['RT', '@Luq_Combs', ':', 'Funniest', 'thing', 'I', 'heard', 'this', 'week', '.', 'Wingo', 'tellin', 'me', 'and', 'wood', '.', '"', 'I', "'m", 'scared', '"', '#pow#pow#pow@Cowboy_Wingo']
# rt #AT# #PUNC# funniest thing i heard this week #PUNC# wingo tellin me and wood #PUNC# #PUNC# i 'm scared #PUNC# #HASH#
# ['O', 'O', 'B-NP', 'I-NP', 'I-NP', 'B-NP', 'B-PP', 'B-NP', 'I-NP', 'O', 'B-ADJP', 'I-ADJP', 'B-NP', 'O', 'B-INTJ', 'I-INTJ', 'O', 'B-NP', 'B-VP', 'B-VP', 'O', 'O']
# ['Gotta', 'love', 'the', 'bumper', 'stickers', 'of', 'Fayette', 'County', ':', '"', 'Ever', 'wonder', 'if', 'there', 'is', 'life', 'after', 'death', '?', 'Touch', 'my', 'truck', 'and', "'ll", 'find', 'out', '."']
# gotta love the bumper stickers of fayette county #PUNC# #PUNC# ever wonder if there is life after death #PUNC# touch my truck and 'll find out #PUNC#
# ['B-VP', 'I-VP', 'B-NP', 'B-ADJP', 'I-ADJP', 'B-PP', 'I-PP', 'I-PP', 'B-NP', 'O', 'B-ADVP', 'B-SBAR', 'I-SBAR', 'B-NP', 'B-VP', 'B-NP', 'B-PP', 'B-NP', 'O', 'B-VP', 'B-NP', 'I-NP', 'O', 'B-VP', 'I-VP', 'B-PRT', 'O']
# ['RT', '@4MusicGossip', ':', 'Oh', ',', 'and', 'do', "n't", 'forget', 'that', 'there', "'s", 'another', 'chance', 'to', 'see', '@pink', ':', 'My', 'Story', 'at', '7pm', 'tonight', 'http://bit.ly/hLAnXp']
# rt #AT# #PUNC# oh #PUNC# and do n't forget that there 's another chance to see #AT# #PUNC# my story at #NUM# tonight #URL#
# ['O', 'O', 'O', 'B-INTJ', 'I-INTJ', 'O', 'B-VP', 'I-VP', 'I-VP', 'B-SBAR', 'B-NP', 'B-VP', 'B-NP', 'I-NP', 'B-VP', 'I-VP', 'O', 'O', 'B-NP', 'I-NP', 'B-PP', 'B-NP', 'B-NP', 'O']
# ['@joejonas', '@nickjonas', '@kevinjonas', '@papajonas', '@greggarbo', '@johnlloydtaylor', 'Rock', 'to', 'SECTION', '204', 'tonight', '!!!!']
# #AT# #AT# #AT# #AT# #AT# #AT# rock to section #NUM# tonight #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'B-NP', 'I-NP', 'B-PP', 'B-NP', 'I-NP', 'B-NP', 'O']
# ['@christinamarks_', 'u', 'try', 'to', 'be', 'like', 'April', 'on', 'youtube']
# #AT# u try to be like april on youtube
# ['O', 'B-NP', 'B-VP', 'I-VP', 'I-VP', 'B-PP', 'B-NP', 'B-PP', 'B-NP']
# ['@MeredithLim', 'No', '.', 'Tomorrow', '.']
# #AT# no #PUNC# tomorrow #PUNC#
# ['O', 'B-INTJ', 'O', 'B-NP', 'O']
# ['So', 'I', "'m", 'currently', 'looking', 'at', 'about', '5', 'years', 'and', '3', 'months', 'if', 'I', 'can', 'get', 'out', 'of', 'there', 'within', 'the', 'next', 'month', '.']
# so i 'm currently looking at about #NUM# years and #NUM# months if i can get out of there within the next month #PUNC#
# ['O', 'B-NP', 'B-VP', 'I-VP', 'I-VP', 'B-PP', 'B-PP', 'B-NP', 'I-NP', 'O', 'B-NP', 'I-NP', 'B-SBAR', 'B-NP', 'B-VP', 'I-VP', 'B-PRT', 'B-PP', 'B-NP', 'B-PP', 'B-NP', 'I-NP', 'I-NP', 'O']
# ['RT', '@OMGwhatateen', ':', 'RT', 'if', 'you', 'are', 'happy', 'it', "'s", 'friday', '.', '#OMGwhatateen']
# rt #AT# #PUNC# rt if you are happy it 's friday #PUNC# #HASH#
# ['O', 'O', 'O', 'O', 'B-SBAR', 'B-NP', 'B-VP', 'B-NP', 'B-NP', 'B-VP', 'B-NP', 'O', 'O']
# ['#blackholidays', '"', 'National', 'forget', 'the', 'he', 'say', 'she', 'say', '...', 'what', 'do', 'God', 'say', 'day', '"']
# #HASH# #PUNC# national forget the he say she say #PUNC# what do god say day #PUNC#
# ['O', 'O', 'B-NP', 'B-VP', 'B-NP', 'B-NP', 'B-VP', 'B-NP', 'B-VP', 'O', 'B-NP', 'B-VP', 'B-NP', 'B-VP', 'B-NP', 'O']
# ['@msloaf', 'Though', 'I', 'do', 'agree', 'that', 'it', 'is', 'offensive', 'and', 'would', 'be', 'difficult', 'to', 'explain', '.', 'When', 'this', 'stuff', 'happens', 'to', 'me', 'I', 'want', 'to', 'yell', ',', '"', 'URDUMB', '!"']
# #AT# though i do agree that it is offensive and would be difficult to explain #PUNC# when this stuff happens to me i want to yell #PUNC# #PUNC# urdumb #PUNC#
# ['O', 'B-ADVP', 'B-NP', 'B-VP', 'B-VP', 'B-NP', 'B-NP', 'B-VP', 'B-NP', 'O', 'B-VP', 'I-VP', 'I-VP', 'I-VP', 'B-PRT', 'O', 'B-ADVP', 'B-NP', 'I-NP', 'B-VP', 'B-PP', 'B-NP', 'B-NP', 'B-VP', 'I-VP', 'B-PRT', 'O', 'O', 'O', 'O']
# ['RT', '@Eeenie_Meenie', ':', 'RT', 'if', 'you', 'are', 'happy', 'that', 'today', 'is', 'FRIDAY', '!', ':)']
# rt #AT# #PUNC# rt if you are happy that today is friday #PUNC# #PUNC#
# ['O', 'O', 'O', 'O', 'B-SBAR', 'B-NP', 'B-VP', 'B-NP', 'B-SBAR', 'B-NP', 'B-VP', 'B-NP', 'O', 'O']
# ['People', 'who', 'tweet', 'to', 'follow', '@GuyGirlTweets', 'will', 'get', 'huge', 'shout', 'outs', 'from', 'me', ':)', 'Just', 'tell', 'me', 'when', 'you', 'do', '!']
# people who tweet to follow #AT# will get huge shout outs from me #PUNC# just tell me when you do #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Was', 'hard', 'work', 'going', 'to', 'the', 'gym', 'on', 'my', 'own', 'tonight', 'but', 'managed', 'a', '30', 'min', 'run', 'and', 'plenty', 'of', 'weights', '.', 'Catching', 'up', 'on', 'ufc', 'now']
# was hard work going to the gym on my own tonight but managed a #NUM# min run and plenty of weights #PUNC# catching up on ufc now
# ['B-VP', 'B-NP', 'I-NP', 'B-VP', 'B-PP', 'B-NP', 'I-NP', 'B-PP', 'B-NP', 'I-NP', 'B-NP', 'O', 'B-VP', 'B-NP', 'I-NP', 'B-VP', 'I-VP', 'I-VP', 'B-PRT', 'B-PP', 'B-NP', 'O', 'B-VP', 'B-PRT', 'B-PP', 'B-NP', 'B-ADVP']
# ['@paulwalk', 'It', "'s", 'the', 'view', 'from', 'where', 'I', "'m", 'living', 'for', 'two', 'weeks', '.', 'Empire', 'State', 'Building', '=', 'ESB', '.', 'Pretty', 'bad', 'storm', 'here', 'last', 'evening', '.']
# #AT# it 's the view from where i 'm living for two weeks #PUNC# empire state building #PUNC# esb #PUNC# pretty bad storm here last evening #PUNC#
# ['O', 'B-NP', 'B-VP', 'B-NP', 'B-ADJP', 'B-PP', 'B-ADVP', 'B-NP', 'B-VP', 'I-VP', 'B-PP', 'B-NP', 'I-NP', 'O', 'B-VP', 'B-NP', 'B-PRT', 'O', 'B-ADVP', 'O', 'B-ADVP', 'I-ADVP', 'B-INTJ', 'B-ADVP', 'B-NP', 'I-NP', 'O']
# ['RT', '@DesignerDepot', ':', 'Minimalist', 'Web', 'Design', ':', 'When', 'Less', 'is', 'More', '-', 'http://ow.ly/2FwyX']
# rt #AT# #PUNC# minimalist web design #PUNC# when less is more #PUNC# #URL#
# ['O', 'O', 'O', 'B-SBAR', 'B-NP', 'I-NP', 'O', 'B-ADVP', 'B-NP', 'B-VP', 'B-ADJP', 'O', 'O']
# ['No', 'bike', "t'day", ':(']
# no bike t'day #PUNC#
# ['B-NP', 'I-NP', 'I-NP', 'O']
# ['bruise', 'on', 'my', 'facee', '...', 'wild', 'night', '!']
# bruise on my facee #PUNC# wild night #PUNC#
# ['B-VP', 'B-PP', 'B-NP', 'I-NP', 'I-NP', 'I-NP', 'I-NP', 'O']
# ['plez', 'check', 'https://owensoto.wordpress.com/', '(', 'my', 'blog', ')', '__AND__', 'http://www.youtube.com/user/22Soto22?feature=mhum', '(', 'my', 'youtube', 'channel', ')', 'if', 'u', 'have', 'time']
# plez check https://owensoto.wordpress.com/ #PUNC# my blog #PUNC# __and__ #URL# #PUNC# my youtube channel #PUNC# if u have time
# ['B-NP', 'B-VP', 'B-ADJP', 'O', 'B-NP', 'I-NP', 'O', 'O', 'O', 'O', 'B-NP', 'B-NP', 'O', 'O', 'B-SBAR', 'B-NP', 'B-VP', 'B-NP']
# ['@jaredleto', '...', 'ive', 'been', 'to', '13', '30stm', 'concerts', 'now', 'and', 'you', 'never', 'got', 'me', 'on', 'stage', 'during/before', 'kings', 'and', 'queens', ':(', '((']
# #AT# #PUNC# ive been to #NUM# #NUM# concerts now and you never got me on stage during/before kings and queens #PUNC# #PUNC#
# ['O', 'O', 'B-NP', 'B-VP', 'I-VP', 'B-NP', 'I-NP', 'B-ADVP', 'I-ADVP', 'I-ADVP', 'B-NP', 'B-ADVP', 'B-VP', 'B-NP', 'B-PP', 'B-NP', 'B-PP', 'I-PP', 'I-PP', 'B-NP', 'O', 'O']
# ['http://bit.ly/aTTQYq', 'When', 'Pepsi', 'to', 'ring', 'usually', 'confirm', 'to', ',', 'winning', 'a', 'Nokia', '5800', '?']
# #URL# when pepsi to ring usually confirm to #PUNC# winning a nokia #NUM# #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['@Jezkwon', '@kpop_stuff', 'Tweet', 'me', 'a', 'member', 'for', 'picspam', '.', 'Will', 'do', 'them', 'tomorrow', 'morning', '.', '(', ':']
# #AT# #AT# tweet me a member for picspam #PUNC# will do them tomorrow morning #PUNC# #PUNC# #PUNC#
# ['O', 'O', 'B-VP', 'B-NP', 'B-NP', 'I-NP', 'B-PP', 'B-NP', 'O', 'B-VP', 'I-VP', 'B-NP', 'B-NP', 'I-NP', 'O', 'O', 'O']
# ['@BexsterBexster', '@shinobi32768', 'I', "'ve", 'been', 'having', 'soup', 'all', 'week', ',', 'do', "n't", 'really', 'have', 'a', 'favourite', '.', 'It', "'s", 'starting', 'to', 'taste', 'pretty', 'much', 'the', 'same', '.']
# #AT# #AT# i 've been having soup all week #PUNC# do n't really have a favourite #PUNC# it 's starting to taste pretty much the same #PUNC#
# ['O', 'O', 'B-NP', 'B-VP', 'I-VP', 'I-VP', 'B-PRT', 'B-NP', 'I-NP', 'O', 'B-VP', 'I-VP', 'B-ADVP', 'B-VP', 'B-NP', 'I-NP', 'O', 'B-NP', 'B-VP', 'I-VP', 'I-VP', 'B-ADVP', 'I-ADVP', 'I-ADVP', 'B-NP', 'I-NP', 'O']
# HBox(children=(IntProgress(value=0, description='Transitions', max=28199, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='Emissions', max=28199, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='FR', max=3700, style=ProgressStyle(description_width='initial…
# ['Petite', 'salle', 'ambiance', 'plage', 'Oléronaise', '.']
# petite salle ambiance plage oléronaise #PUNC#
# ['O', 'O', 'B-positive', 'I-positive', 'I-positive', 'O']
# ['La', 'salle', 'est', 'jolie', 'et', 'bien', 'chauffée', '.']
# la salle est jolie et bien chauffée #PUNC#
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Ça', 'ne', 'les', 'vaut', 'pas', '.']
# ça ne les vaut pas #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O']
# ['A', 'ne', 'surtout', 'pas', 'manquer', '.']
# a ne surtout pas manquer #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O']
# ['Alors', 'là', ',', 'si', 'vous', 'voulez', 'un', 'resto', 'classe', ',', 'une', 'cuisine', 'très', 'soignée', 'et', 'rafinée', 'pour', 'féter', 'un', 'anniversaire', ',', 'ou', 'une', 'grande', 'occasion', ',', "c'est", 'le', 'lieu', 'IDEAL', '!']
# alors là #PUNC# si vous voulez un resto classe #PUNC# une cuisine très soignée et rafinée pour féter un anniversaire #PUNC# ou une grande occasion #PUNC# c'est le lieu ideal #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'B-neutral', 'O', 'B-neutral', 'I-neutral', 'I-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'I-positive', 'O']
# ['Nous', 'avons', 'eu', 'le', 'tort', 'de', 'nous', 'rabattre', 'sur', 'un', 'burger', 'et', 'un', 'fish', 'and', 'chips', ',', 'erreur', 'fatale', ':', 'burger', 'moyen', ',', 'frites', 'molles', 'et', 'grasses', ',', 'quant', 'au', 'fish', 'and', 'chips', 'impression', "d'ingurgiter", 'uniquement', 'de', 'la', 'pâte', 'à', 'friture', 'baignée', 'de', 'graisse', '.']
# nous avons eu le tort de nous rabattre sur un burger et un fish and chips #PUNC# erreur fatale #PUNC# burger moyen #PUNC# frites molles et grasses #PUNC# quant au fish and chips impression d'ingurgiter uniquement de la pâte #PUNC# friture baignée de graisse #PUNC#
# ['O', 'O', 'O', 'O', 'B-neutral', 'I-neutral', 'O', 'B-neutral', 'O', 'O', 'B-negative', 'O', 'O', 'O', 'O', 'B-negative', 'O', 'O', 'O', 'O', 'B-negative', 'O', 'O', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O']
# ['mais', 'une', 'impression', "d'inachevé", '.']
# mais une impression d'inachevé #PUNC#
# ['O', 'O', 'O', 'O', 'O']
# ['Temps', "d'attente", 'trop', 'long', 'et', 'manque', 'évident', "d'organisation", '.']
# temps d'attente trop long et manque évident d'organisation #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'I-neutral', 'O']
# ['Le', 'restaurant', 'est', 'très', 'bien', 'situé', ',', 'proche', 'du', 'Sacré', 'Coeur', '.']
# le restaurant est très bien situé #PUNC# proche du sacré coeur #PUNC#
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['En', 'dessert', ',', 'en', 'plus', 'de', "l'incontournable", 'tarte', 'au', 'citron', 'servie', 'autrement', ',', 'nous', 'nous', 'sommes', 'également', 'régalés', 'avec', 'la', 'brioche', 'perdue', '...', 'Superbe', '!']
# en dessert #PUNC# en plus de l'incontournable tarte au citron servie autrement #PUNC# nous nous sommes également régalés avec la brioche perdue #PUNC# superbe #PUNC#
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Il', 'ne', 'manquait', 'que', 'la', 'fameuse', 'boite', 'de', 'bonbons', 'à', 'la', 'fin', 'du', 'repas', '!']
# il ne manquait que la fameuse boite de bonbons #PUNC# la fin du repas #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'B-neutral', 'I-neutral', 'I-neutral', 'I-neutral', 'O', 'O', 'O', 'O', 'O', 'O']
# ['La', 'ballade', 'romantique', 'apres', 'le', 'repas', "s'impose", '.']
# la ballade romantique apres le repas s'impose #PUNC#
# ['O', 'B-neutral', 'O', 'O', 'O', 'B-positive', 'I-positive', 'O']
# ['Déjà', 'en', 'arrivant', ',', 'le', 'cadre', 'est', 'exceptionnel', '!']
# déjà en arrivant #PUNC# le cadre est exceptionnel #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O']
# ['Superbe', 'cadre', 'si', 'on', 'mange', 'dehors', '.']
# superbe cadre si on mange dehors #PUNC#
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O']
# ['Cette', 'salle', 'dansante', 'est', 'agréable', 'malgré', 'son', 'étroitesse', 'nous', 'nous', 'sommes', 'amusés', 'mais', 'il', 'y', 'avait', 'peu', 'de', 'monde', 'alors', 'je', 'ne', 'sais', 'pas', 'si', 'le', 'plaisir', 'est', 'toujours', 'là', 'les', 'soirs', "d'affluence", '.']
# cette salle dansante est agréable malgré son étroitesse nous nous sommes amusés mais il y avait peu de monde alors je ne sais pas si le plaisir est toujours là les soirs d'affluence #PUNC#
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['On', 'commande', 'quand', 'même', ',', 'lasagnes', 'pâteuses', ',', 'avec', 'beaucoup', 'de', 'fromage', 'sans', 'saveur', 'sur', 'le', 'dessus', ',', 'ce', 'qui', 'atténuait', "l'acidité", 'du', 'concentré', 'de', 'tomates', '...', '!']
# on commande quand même #PUNC# lasagnes pâteuses #PUNC# avec beaucoup de fromage sans saveur sur le dessus #PUNC# ce qui atténuait l'acidité du concentré de tomates #PUNC# #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'B-positive', 'I-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'I-neutral', 'I-neutral', 'I-neutral', 'O', 'O', 'O', 'O']
# ['Les', 'tarifs', 'sont', 'au', 'dessus', 'de', 'la', 'moyenne', 'Parisienne', 'au', 'regard', 'de', 'la', 'prestation', 'tout', 'aussi', 'banale', '.']
# les tarifs sont au dessus de la moyenne parisienne au regard de la prestation tout aussi banale #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['le', 'service', 'est', 'nickel', '.']
# le service est nickel #PUNC#
# ['O', 'B-positive', 'I-positive', 'I-positive', 'O']
# ['Attente', 'démesurée', ',', 'le', 'vin', 'demandé', "n'est", 'plus', 'en', 'cave', ',', 'mais', 'on', 'ne', 'nous', 'en', 'propose', 'pas', "d'autre", '!']
# attente démesurée #PUNC# le vin demandé n'est plus en cave #PUNC# mais on ne nous en propose pas d'autre #PUNC#
# ['B-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['La', 'musique', 'était', 'vraiment', 'très', 'forte', '.']
# la musique était vraiment très forte #PUNC#
# ['O', 'B-negative', 'O', 'O', 'O', 'O', 'O']
# ['A', 'éviter', '!', '!', '!']
# a éviter #PUNC# #PUNC# #PUNC#
# ['O', 'O', 'O', 'O', 'O']
# ['Desserts', 'originaux', 'et', 'légers', '.']
# desserts originaux et légers #PUNC#
# ['B-negative', 'O', 'O', 'O', 'O']
# ["C'est", 'un', 'bon', 'rapport', 'qualité', '/', 'prix', '.']
# c'est un bon rapport qualité #PUNC# prix #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Enfin', 'la', 'masterpiece', ':', 'le', 'riz', 'au', 'lait', 'vanille', 'sauce', 'caramel', 'beurre', 'salé', '(', 'divin', ')', '.']
# enfin la masterpiece #PUNC# le riz au lait vanille sauce caramel beurre salé #PUNC# divin #PUNC# #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Personnel', 'hyper', 'sympa', 'et', 'de', 'bon', 'conseil', '.']
# personnel hyper sympa et de bon conseil #PUNC#
# ['B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['On', 'y', 'va', 'les', 'yeux', 'fermés', '!']
# on y va les yeux fermés #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Bonne', 'cuisine', ',', 'un', 'petit', 'bémol', 'pour', 'le', 'service', '.']
# bonne cuisine #PUNC# un petit bémol pour le service #PUNC#
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'B-negative', 'O']
# ['Nous', 'avons', 'été', 'attiré', 'comme', 'les', 'autres', 'personnes', 'par', 'la', 'terrasse', 'et', 'les', 'prix', 'bas', '.']
# nous avons été attiré comme les autres personnes par la terrasse et les prix bas #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O']
# ['A', 'la', 'carte', ',', 'plus', 'cher', ',', 'la', 'sole', 'meunière', 'est', 'un', 'véritable', 'délice', '(', '49', 'euros', 'tout', 'de', 'même', ')', 'et', 'chacun', 'sait', 'à', 'quel', 'point', "c'est", 'difficile', 'de', 'la', 'réussir', '.']
# a la carte #PUNC# plus cher #PUNC# la sole meunière est un véritable délice #PUNC# #NUM# euros tout de même #PUNC# et chacun sait #PUNC# quel point c'est difficile de la réussir #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'I-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Arrivez', 'tôt', 'car', 'ça', 'se', 'remplit', 'rapidement', '.']
# arrivez tôt car ça se remplit rapidement #PUNC#
# ['B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Juste', 'un', 'peu', 'déçu', 'sur', 'l', "'", 'assaisonnement', '.']
# juste un peu déçu sur l #PUNC# assaisonnement #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O']
# ['Entrées', 'a', 'partager', ':', 'tres', 'bonnes', '!']
# entrées a partager #PUNC# tres bonnes #PUNC#
# ['B-positive', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Cet', 'écriteau', 'était', 'bien', 'caché', 'à', "l'intérieur", 'de', "l'établissement", 'pour', 'ne', 'pas', 'que', 'les', 'clients', 'en', 'terrasse', 'le', 'voient', '.']
# cet écriteau était bien caché #PUNC# l'intérieur de l'établissement pour ne pas que les clients en terrasse le voient #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'B-positive', 'O']
# ['Je', 'ne', 'parle', 'pas', 'des', 'accompagnements', '!']
# je ne parle pas des accompagnements #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Une', 'catastrophe', 'à', 'éviter', 'absolument', '.']
# une catastrophe #PUNC# éviter absolument #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O']
# ['La', 'côte', 'de', 'veau', 'aussi', '.']
# la côte de veau aussi #PUNC#
# ['O', 'B-negative', 'I-negative', 'I-negative', 'O', 'O']
# ['A', 'la', 'place', 'une', 'espèce', 'de', 'confit', 'de', 'tomates', 'au', 'citron', 'tout', 'simplement', 'immangeable', '.']
# a la place une espèce de confit de tomates au citron tout simplement immangeable #PUNC#
# ['O', 'O', 'O', 'O', 'B-negative', 'I-negative', 'I-negative', 'I-negative', 'I-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O']
# ['Ce', "n'est", 'pas', 'pour', 'le', 'régime', '.']
# ce n'est pas pour le régime #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Le', 'personnel', 'est', 'tres', 'attentionné', '.']
# le personnel est tres attentionné #PUNC#
# ['O', 'B-positive', 'O', 'O', 'O', 'O']
# ['concept', 'étonnant', 'au', 'départ', 'mais', 'très', 'éfficace', 'car', 'la', 'cuisine', 'est', 'bonne', 'et', 'l', "'", 'endroit', 'convivial', '!', '!', 'le', 'tartare', 'est', 'excélent', 'et', 'les', 'frites', 'maison', 'sont', 'a', 'volonté', 'pour', 'un', 'prix', 'tout', 'a', 'fait', 'convenable', '!']
# concept étonnant au départ mais très éfficace car la cuisine est bonne et l #PUNC# endroit convivial #PUNC# #PUNC# le tartare est excélent et les frites maison sont a volonté pour un prix tout a fait convenable #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['En', 'somme', 'un', 'Resto', 'où', 'on', 'peut', 'venir', 'entre', 'amis', 'pour', 'bien', 'manger', 'et', 'de', 'manière', 'rapide', 'si', 'on', 'le', 'souhaite']
# en somme un resto où on peut venir entre amis pour bien manger et de manière rapide si on le souhaite
# ['O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Nous', 'y', 'sommes', 'allés', 'le', 'midi', 'entre', 'collègues', 'et', "c'était", 'très', 'bien', '.']
# nous y sommes allés le midi entre collègues et c'était très bien #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Continuez', 'comme', 'ça', 'je', 'vous', 'encourage', 'chaudement', '!']
# continuez comme ça je vous encourage chaudement #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Le', 'dessert', ',', 'une', 'soupe', 'de', 'fraises', 'au', 'basilic', 'était', 'correct', '.']
# le dessert #PUNC# une soupe de fraises au basilic était correct #PUNC#
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['TOUTES', 'LES', 'VIANDES', 'SONT', 'SANS', 'GOUT', 'ET', 'SECHES', '!', '!', '!']
# toutes les viandes sont sans gout et seches #PUNC# #PUNC# #PUNC#
# ['O', 'O', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Depuis', 'nous', 'y', 'avons', 'déjeuner', 'et', 'dîner', 'à', 'plusieurs', 'reprises', '.']
# depuis nous y avons déjeuner et dîner #PUNC# plusieurs reprises #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ["J'y", 'suis', 'allé', 'plusieurs', 'fois', "l'an", 'passé', "c'était", 'très', 'correcte', 'mais', 'à', 'priori', 'quelque', 'chose', 'a', 'changé', 'en', 'cuisine', 'par', 'rapport', 'à', "l'an", 'dernier', 'car', "c'est", 'devenu', 'un', 'vrai', 'cauchemar', '.']
# j'y suis allé plusieurs fois l'an passé c'était très correcte mais #PUNC# priori quelque chose a changé en cuisine par rapport #PUNC# l'an dernier car c'est devenu un vrai cauchemar #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Jeudi', 'dernier', 'nous', 'avons', 'particulièrement', 'apprécié', 'l', "'", 'échine', 'de', 'cochon', 'confite', 'avec', 'ses', 'gnocchis', '(', 'les', 'meilleures', 'que', "j'ai", 'été', 'amené', 'à', 'goûter', ')', 'et', 'ses', 'girolles', '.']
# jeudi dernier nous avons particulièrement apprécié l #PUNC# échine de cochon confite avec ses gnocchis #PUNC# les meilleures que j'ai été amené #PUNC# goûter #PUNC# et ses girolles #PUNC#
# ['B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'I-neutral', 'I-neutral', 'I-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['La', 'voisine', 'à', 'la', 'table', "d'à", 'côté', 'a', 'renvoyé', 'son', 'verre', 'de', 'vin', 'blanc', 'sous', 'prétexte', "qu'il", 'y', 'avait', 'tellement', 'de', 'glaçons', "qu'elle", "n'avait", 'plus', 'le', 'goût', 'du', 'vin', '.']
# la voisine #PUNC# la table d'à côté a renvoyé son verre de vin blanc sous prétexte qu'il y avait tellement de glaçons qu'elle n'avait plus le goût du vin #PUNC#
# ['O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-negative', 'I-negative', 'I-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Beaucoup', 'trop', 'de', 'tables', 'pour', 'la', 'surface', ',', 'les', 'clients', 'sont', 'entassés', '.']
# beaucoup trop de tables pour la surface #PUNC# les clients sont entassés #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Je', 'le', 'conseille', 'vivement', '.']
# je le conseille vivement #PUNC#
# ['O', 'O', 'O', 'O', 'O']
# ['Dommage', 'que', 'mon', 'avis', "n'est", 'était', 'entendu', 'pendant', 'le', 'repas', '.']
# dommage que mon avis n'est était entendu pendant le repas #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Peu', 'de', 'choix', 'à', 'la', 'carte', ',', 'mais', "c'est", 'aussi', 'comme', 'ça', "qu'on", 'a', 'plus', 'de', 'chance', 'de', 'faire', 'des', 'bons', 'plats', '!']
# peu de choix #PUNC# la carte #PUNC# mais c'est aussi comme ça qu'on a plus de chance de faire des bons plats #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Longue', 'attente', 'encore', 'pour', 'avoir', 'ses', 'boissons', '.']
# longue attente encore pour avoir ses boissons #PUNC#
# ['O', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Dessert', ':', 'mousse', 'aux', '2', 'chocolats', ',', 'bonne', 'mais', 'beaucoup', 'trop', 'sucrée', '.']
# dessert #PUNC# mousse aux #NUM# chocolats #PUNC# bonne mais beaucoup trop sucrée #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Choix', 'de', 'dessert', 'quasi', 'inexistant', '.']
# choix de dessert quasi inexistant #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O']
# ['Le', 'spaguetti', 'carbonara', 'qui', 'baigne', 'dans', 'la', 'crème', 'complètement', 'liquide', ',', 'l', "'", 'accueil', 'pas', 'très', 'agréable', ',', 'je', "n'y", 'retournerais', 'pas', '.']
# le spaguetti carbonara qui baigne dans la crème complètement liquide #PUNC# l #PUNC# accueil pas très agréable #PUNC# je n'y retournerais pas #PUNC#
# ['O', 'B-neutral', 'I-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Les', 'galettes', 'sont', 'copieuses', 'et', 'les', 'crêpes', 'excellentes', ',', 'fines', 'et', 'légères', '.']
# les galettes sont copieuses et les crêpes excellentes #PUNC# fines et légères #PUNC#
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-negative', 'I-negative', 'I-negative', 'O']
# ['Une', 'belle', 'erreur', 'de', 'choix', 'de', 'notre', 'part', '.']
# une belle erreur de choix de notre part #PUNC#
# ...
# ['B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'I-neutral', 'I-neutral', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Évitez', "d'y", 'aller', 'en', 'gros', 'groupe', ',', 'six', 'personnes', "c'est", 'déjà', 'beaucoup', '.']
# évitez d'y aller en gros groupe #PUNC# six personnes c'est déjà beaucoup #PUNC#
# ['B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Nous', 'étions', '5', 'et', 'avons', 'gouté', '2', 'entrées', ',', '5', 'plats', 'et', '4', 'desserts', ',', 'tous', 'excellents', 'et', 'très', 'bien', 'préparés', ',', 'particulièrement', 'les', 'entrées', '.']
# nous étions #NUM# et avons gouté #NUM# entrées #PUNC# #NUM# plats et #NUM# desserts #PUNC# tous excellents et très bien préparés #PUNC# particulièrement les entrées #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Je', 'suis', 'bien', 'conscient', 'que', 'cet', 'avis', 'ne', 'changera', 'rien', ',', 'le', 'bar', 'étant', 'placé', 'de', 'manière', 'à', 'toujours', 'pouvoir', 'attirer', 'des', 'touristes', 'mais', 'bon', ',', 'un', 'lieu', 'aussi', 'scandaleux', 'merite', "d'être", 'dénoncé', '.']
# je suis bien conscient que cet avis ne changera rien #PUNC# le bar étant placé de manière #PUNC# toujours pouvoir attirer des touristes mais bon #PUNC# un lieu aussi scandaleux merite d'être dénoncé #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Les', 'nems', 'sont', 'corrects', ',', 'les', 'quantités', 'sont', 'petites', '(', 'nous', 'sommes', 'sortis', 'en', 'ayant', 'à', 'peine', 'assez', 'mangé', ')', ',', 'le', 'poulet', 'croustillant', 'ne', "l'est", 'pas', 'et', 'baigne', 'dans', 'le', 'gras', '.']
# les nems sont corrects #PUNC# les quantités sont petites #PUNC# nous sommes sortis en ayant #PUNC# peine assez mangé #PUNC# #PUNC# le poulet croustillant ne l'est pas et baigne dans le gras #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Nous', 'avons', 'vécu', 'une', 'expérience', 'culinaire', 'hors', 'du', 'commun', '.']
# nous avons vécu une expérience culinaire hors du commun #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['A', 'recommander', '1000', 'fois', '!']
# a recommander #NUM# fois #PUNC#
# ['O', 'O', 'O', 'O', 'O']
# ['Lors', 'du', 'festival', 'des', 'barques', ',', 'nous', 'sommes', 'arrivés', 'par', 'hasard', 'sur', 'cette', 'placette', '.']
# lors du festival des barques #PUNC# nous sommes arrivés par hasard sur cette placette #PUNC#
# ['O', 'O', 'B-neutral', 'I-neutral', 'I-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Nous', 'nous', 'ferons', 'ensuite', 'de', 'nouveau', 'insulter', 'par', 'le', 'responsable', 'avant', "qu'il", 'accepte', "d'encaisser", 'nos', 'boissons', 'et', 'de', 'nous', 'laisser', 'partir', '.']
# nous nous ferons ensuite de nouveau insulter par le responsable avant qu'il accepte d'encaisser nos boissons et de nous laisser partir #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Quel', 'gâchis', '.']
# quel gâchis #PUNC#
# ['O', 'O', 'O']
# ['Pas', 'besoin', "d'en", 'dire', 'plus', ',', 'ce', 'bar', 'est', 'affreux']
# pas besoin d'en dire plus #PUNC# ce bar est affreux
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Nous', 'sommes', 'dans', 'le', 'classique', 'du', 'genre', 'avec', 'peu', 'de', 'surprise', 'et', 'des', 'prix', 'plutôt', 'élevés', '.']
# nous sommes dans le classique du genre avec peu de surprise et des prix plutôt élevés #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Les', 'anciens', 'patrons', 'navaient', 'rien', 'avoir', ',', 'la', 'patronne', 'ny', 'connait', 'rien', 'de', 'rien', 'en', 'restauration']
# les anciens patrons navaient rien avoir #PUNC# la patronne ny connait rien de rien en restauration
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-negative', 'I-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O']
# ['Les', 'points', 'négatifs', 'sont', 'le', 'manque', "d'espace", '(', 'les', 'tables', 'sont', 'petites', 'et', 'très', 'rapprochées', ')', ',', 'l', "'", 'environnement', 'plutôt', 'bruyant', 'et', 'le', 'délai', 'd', "'", 'attente', 'avant', "d'être", 'servis', '(', '45', 'minutes', 'environ', 'avant', "d'avoir", "l'entrée", ')', '.']
# les points négatifs sont le manque d'espace #PUNC# les tables sont petites et très rapprochées #PUNC# #PUNC# l #PUNC# environnement plutôt bruyant et le délai d #PUNC# attente avant d'être servis #PUNC# #NUM# minutes environ avant d'avoir l'entrée #PUNC# #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Choisissez', 'une', 'table', 'qui', 'vous', 'permet', 'de', 'voir', 'travailler', 'les', 'peintres', 'de', 'Montmartre']
# choisissez une table qui vous permet de voir travailler les peintres de montmartre
# ['B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'B-neutral', 'O', 'O']
# ['Accueil', 'moyen', ',', 'on', 'a', "l'impression", "d'embêter", 'le', 'personnel', '.']
# accueil moyen #PUNC# on a l'impression d'embêter le personnel #PUNC#
# ['B-positive', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'B-positive', 'O']
# ['l', "'", 'accueil', 'est', 'agréable', ';', 'la', 'cuisine', 'correcte', ',', 'les', 'prix', 'raisonnables', ',', 'bref', "c'est", 'bien', 'mais', 'est-ce', 'le', 'nombre', 'de', 'gens', ',', 'la', 'salle', ',', '...', 'il', 'manque', 'un', 'petit', 'quelque', 'chose', 'pour', "s'enthousiasmer", '.']
# l #PUNC# accueil est agréable #PUNC# la cuisine correcte #PUNC# les prix raisonnables #PUNC# bref c'est bien mais est-ce le nombre de gens #PUNC# la salle #PUNC# #PUNC# il manque un petit quelque chose pour s'enthousiasmer #PUNC#
# ['O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['La', 'tarte', 'tatin', 'divine']
# la tarte tatin divine
# ['O', 'B-positive', 'I-positive', 'O']
# ['Bref', ',', 'le', 'repas', "n'était", 'pas', 'mauvais', 'mais', 'je', "n'ai", 'pas', 'été', 'emballé', '.']
# bref #PUNC# le repas n'était pas mauvais mais je n'ai pas été emballé #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Les', 'plats', 'arrivent', 'rapidement', '.']
# les plats arrivent rapidement #PUNC#
# ['O', 'B-positive', 'O', 'O', 'O']
# ["J'adore", 'ces', 'restaurants', 'où', 'on', 'a', 'toujours', 'du', 'vin', 'dans', 'notre', 'coupe', 'sans', 'jamais', 'avoir', 'à', 'toucher', 'à', 'la', 'bouteille', ',', 'pour', 'moi', 'çà', 'témoigne', 'que', 'le', 'personnel', 'garde', 'toujours', 'un', 'oeil', 'sur', 'vous', 'pour', 'vous', 'servir', '.']
# j'adore ces restaurants où on a toujours du vin dans notre coupe sans jamais avoir #PUNC# toucher #PUNC# la bouteille #PUNC# pour moi #PUNC# témoigne que le personnel garde toujours un oeil sur vous pour vous servir #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'I-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Endroit', 'sympa', 'en', 'plein', 'centre', 'touristique', '.']
# endroit sympa en plein centre touristique #PUNC#
# ['B-positive', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Le', 'plat', 'du', 'jour', 'comme', 'son', 'nom', "l'indique", 'est', 'plutôt', 'un', 'gage', 'de', 'fraicheur', 'et', 'qualité', ';', 'ce', 'jour', 'là', 'si', 'le', 'sanglier', 'était', 'convenable', ',', 'l', "'", 'accompagnement', 'très', 'limite', 'à', 'savoir', 'des', 'pâtes', 'desséchées', 'et', 'froides', '.']
# le plat du jour comme son nom l'indique est plutôt un gage de fraicheur et qualité #PUNC# ce jour là si le sanglier était convenable #PUNC# l #PUNC# accompagnement très limite #PUNC# savoir des pâtes desséchées et froides #PUNC#
# ['O', 'B-neutral', 'I-neutral', 'I-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'I-neutral', 'I-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-negative', 'I-negative', 'I-negative', 'O', 'O']
# ['Mais', 'comment', 'peux', 'on', 'mettre', '5', 'étoiles', 'à', 'un', 'resto', '"', 'asiatique', '"', 'ou', 'tout', "n'est", 'que', 'du', 'réchauffé', ',', 'décongelé', 'provenant', 'de', 'métro', 'ou', 'promocash', '.']
# mais comment peux on mettre #NUM# étoiles #PUNC# un resto #PUNC# asiatique #PUNC# ou tout n'est que du réchauffé #PUNC# décongelé provenant de métro ou promocash #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Et', 'faites', 'le', 'détour', ',', 'pour', 'un', 'cassoulet', 'top', 'et', 'généreux', '.']
# et faites le détour #PUNC# pour un cassoulet top et généreux #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Vin', 'au', 'verre', '(', 'heureusement', '!', ')', '.']
# vin au verre #PUNC# heureusement #PUNC# #PUNC# #PUNC#
# ['B-negative', 'I-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O']
# ['Cet', 'endroit', 'mériterait', "d'etre", 'ouvert', 'plus', 'souvent', 'et', "d'avoir", 'plus', 'de', 'place', 'et', 'du', 'personnel', '.']
# cet endroit mériterait d'etre ouvert plus souvent et d'avoir plus de place et du personnel #PUNC#
# ['O', 'B-positive', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O']
# ['Vraiment', 'très', 'dépaysant', '!']
# vraiment très dépaysant #PUNC#
# ['O', 'O', 'O', 'O']
# ['Les', 'vins', 'sont', 'bons', 'mais', 'pas', 'excellent', ',', 'les', 'tapas', 'quand', 'il', 'y', 'en', 'a', 'encore', 'sont', 'bonnes', ',', 'heureusement', 'que', 'le', 'personnel', 'est', 'sympathique', '.']
# les vins sont bons mais pas excellent #PUNC# les tapas quand il y en a encore sont bonnes #PUNC# heureusement que le personnel est sympathique #PUNC#
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O']
# ['La', 'déco', 'pourrait', 'être', 'revisité', 'mais', 'l', "'", 'accueil', 'est', 'bon', 'la', 'prise', 'de', 'commande', 'est', 'rapide', 'et', 'très', 'souriante', '.']
# la déco pourrait être revisité mais l #PUNC# accueil est bon la prise de commande est rapide et très souriante #PUNC#
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['De', 'l', "'", 'accueil', 'à', 'la', 'cuisine', 'tout', 'est', 'bas', 'de', 'gamme', ',', 'heureusement', 'le', 'rabatteur', 'est', 'là', 'pour', 'piéger', 'les', 'touristes', 'qui', 'passent', 'par', 'là', '.']
# de l #PUNC# accueil #PUNC# la cuisine tout est bas de gamme #PUNC# heureusement le rabatteur est là pour piéger les touristes qui passent par là #PUNC#
# ['O', 'O', 'O', 'B-positive', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['bon', 'accueil']
# bon accueil
# ['O', 'B-positive']
# ['La', 'tartiflette', 'était', 'correcte', '.']
# la tartiflette était correcte #PUNC#
# ['O', 'B-neutral', 'O', 'O', 'O']
# ['Ici', ',', 'la', 'cuisine', 'française', 'est', 'à', "l'honneur", '.']
# ici #PUNC# la cuisine française est #PUNC# l'honneur #PUNC#
# ['O', 'O', 'O', 'B-positive', 'I-positive', 'I-positive', 'I-positive', 'I-positive', 'O']
# ['Une', 'honte']
# une honte
# ['O', 'O']
# ['Aussi', 'je', 'vous', 'conseille', 'de', 'gouter', 'le', 'mojito', ',', 'un', 'grand', 'verre', 'pour', '5', '€', ',', 'super', 'bon', '.']
# aussi je vous conseille de gouter le mojito #PUNC# un grand verre pour #NUM# #PUNC# #PUNC# super bon #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Les', 'prix', 'sont', 'trop', 'élevés', 'par', 'rapport', 'à', 'ce', "qu'on", 'nous', 'a', 'proposé', '.']
# les prix sont trop élevés par rapport #PUNC# ce qu'on nous a proposé #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Le', 'maître', "d'hôtel", 'méprisant', 'et', 'grossier', '.']
# le maître d'hôtel méprisant et grossier #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Un', 'rapport', 'qualité', 'prix', 'correct', '.']
# un rapport qualité prix correct #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O']
# ['En', 'raison', 'de', 'la', 'chaleur', 'on', 'nous', 'a', 'aimablement', 'conseillé', 'une', 'table', 'dans', 'la', 'salle', 'climatisée', '.']
# en raison de la chaleur on nous a aimablement conseillé une table dans la salle climatisée #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'I-positive', 'O']
# ['Accueil', 'chaleureux', ',', 'arrière', 'salle', 'voûtée', 'magnifique', '(', 'ancien', 'rempart', 'de', 'la', 'ville', ')', ',', 'très', 'bonne', 'cuisine', ',', 'grillades', 'au', 'feu', 'de', 'bois', 'casiement', 'sous', 'nos', 'yeux', ',', 'produits', 'de', 'qualité', 'et', 'prix', 'raisonnable', '.']
# accueil chaleureux #PUNC# arrière salle voûtée magnifique #PUNC# ancien rempart de la ville #PUNC# #PUNC# très bonne cuisine #PUNC# grillades au feu de bois casiement sous nos yeux #PUNC# produits de qualité et prix raisonnable #PUNC#
# ['B-positive', 'O', 'O', 'O', 'B-negative', 'I-negative', 'O', 'O', 'B-neutral', 'I-neutral', 'I-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'B-positive', 'I-positive', 'I-positive', 'I-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Et', 'à', 'chaque', 'fois', ',', 'pas', 'de', 'déception', ':', 'carte', 'variée', ',', 'produits', 'frais', 'et', 'de', 'qualité', ',', 'plats', 'savoureux', ',', 'portions', 'copieuses', 'et', 'service', 'très', 'sympathique', '.']
# et #PUNC# chaque fois #PUNC# pas de déception #PUNC# carte variée #PUNC# produits frais et de qualité #PUNC# plats savoureux #PUNC# portions copieuses et service très sympathique #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'I-positive', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'B-negative', 'O', 'O', 'O']
# ['Un', 'cadre', 'simple', 'mais', 'pourtant', 'très', 'authentique', 'et', 'étudié', '...', 'un', 'style', 'américain', 'années', '70', 'tout', 'en', 'simplicité', 'et', 'goût', '.']
# un cadre simple mais pourtant très authentique et étudié #PUNC# un style américain années #NUM# tout en simplicité et goût #PUNC#
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'B-negative', 'I-negative', 'I-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['La', 'nourriture', ',', 'intolérable', '!']
# la nourriture #PUNC# intolérable #PUNC#
# ['O', 'B-positive', 'O', 'O', 'O']
# ['Une', 'cuisine', 'simple', 'mais', 'goûteuse', 'avec', 'de', 'bons', 'produits', '.']
# une cuisine simple mais goûteuse avec de bons produits #PUNC#
# ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O']
# ['Une', 'table', 'qui', 'tient', 'la', 'route', 'dans', 'un', 'quartier', 'où', 'les', 'tables', 'changent', 'très', 'vite', '?']
# une table qui tient la route dans un quartier où les tables changent très vite #PUNC#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['Menus', 'à', 'prix', 'raisonables', 'et', 'très', 'bonne', 'cave', 'avec', 'des', 'bons', 'conseils', '.']
# menus #PUNC# prix raisonables et très bonne cave avec des bons conseils #PUNC#
# ['B-neutral', 'I-neutral', 'I-neutral', 'I-neutral', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O']
